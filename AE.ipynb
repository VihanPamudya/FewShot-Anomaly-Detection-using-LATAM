# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedKFold, KFold
from sklearn import linear_model, metrics, preprocessing
from math import sqrt, floor
from datetime import datetime, timedelta
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, BatchNormalization, Input, LSTM,Dense,RepeatVector, TimeDistributed , LeakyReLU
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, IsolationForest
from sklearn.metrics import r2_score, make_scorer, accuracy_score, mean_squared_error, mean_absolute_error
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
import tensorflow as tf
LeakyReLU = LeakyReLU(alpha=0.1)
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)
import time
from sklearn.pipeline import make_pipeline, Pipeline
import math
from sklearn.decomposition import PCA
from numpy import array
from keras.utils.vis_utils import plot_model
import keras
from keras.layers import Dense, Dropout, Activation, BatchNormalization, Input,Conv2D, Conv1D, Conv1DTranspose,MaxPooling1D

import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from keras import optimizers, Sequential
from sklearn.metrics import f1_score
import pickle
import ast


path_errors = '/mnt/stud/home/vpulagura/dataset/exp2/errortimestamps.csv'
path_features = '/mnt/stud/home/vpulagura/dataset/exp2/featureslist.csv'
df_errors = pd.read_csv(path_errors)
df_features = pd.read_csv(path_features)
total_features = list(df_features[(df_features['True/False'] == 'TRUE') | (df_features['True/False'] == 'NotAvailable')]['Features'])
tot_feat = pd.read_csv('/mnt/stud/home/vpulagura/experiment/AutoencoderModels/totfeat.csv')
tot_feat = list(tot_feat['feat'])

def create_directory(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)

def flatten(X):
    flattened_X = np.empty((X.shape[0], X.shape[2]))  # sample x features array.
    for i in range(X.shape[0]):
        flattened_X[i] = X[i, (X.shape[1]-1), :]
    return(flattened_X)


def encoder(input_dim, encoding_dim, layer1, layer2):
    x = Dense(layer1, activation = 'relu')(input_dim)
    x = Dense(layer2, activation = 'relu')(x)
    x = Dense(encoding_dim, activation = 'relu')(x)
    return x

def decoder(encoding_dim, decod_dim, layer1, layer2):
    x = Dense(layer2, activation = 'relu')(encoding_dim)
    x = Dense(layer1, activation = 'relu')(x)
    x = Dense(decod_dim, activation = 'relu')(x)
    return x

def create_autoencoder_model2(encoding_dim = 35, input_dim = 137, decod_dim=137,layer1=60, layer2=80):
    input_dim = Input(shape = (input_dim, ))
    encoder_out = encoder(input_dim, encoding_dim, layer1, layer2)
    decoder_out = decoder(encoder_out, decod_dim, layer1, layer2)
    autoencoder = Model(inputs = input_dim, outputs = decoder_out)
    autoencoder.compile(optimizer = 'adam', loss = 'mse')
    return autoencoder

def getHyperParams(file, df_hyp):
    param_dict = ast.literal_eval(df_hyp.loc[df_hyp['Inverter'] == file]['Feature Importance'].values[0])
    print(param_dict)
    return param_dict['model__batch_size'], param_dict['model__encoding_dim'], param_dict['model__epochs'],param_dict['model__layer1'], param_dict['model__layer2'] 

callback1 = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, verbose=1)
dayWiseResultsTest = {}
dayWiseResultsTrain = {}
for itr in range(3,4):
    SMA_RESULTS_PATH_TRAIN = f'/mnt/stud/home/vpulagura/experiment/SMA_2W_1M_3M/Results/Iter{itr}/train/'
    SMA_RESULTS_PATH_TEST = f'/mnt/stud/home/vpulagura/experiment/SMA_2W_1M_3M/Results/Iter{itr}/test/'
    for dayStart in [14, 30, 90]:
        hyp = '2W' if dayStart == 14 else '1M' if dayStart == 30 else '3M' 
        df_hyp = pd.read_csv(f"/mnt/stud/home/vpulagura/experiment/SMA_2W_1M_3M/Hyperparameters/AE{hyp}.csv")
        print(dayStart)
        daysrange = str(dayStart)
        source_dict_results = {}
        source_dict_results_train = {}
        lst=[]
        for i in range(19):
            tot_feat.append('ErrBits')
            print(i)
            inverter = i
            df_inv_0 = pd.read_csv(f'/mnt/stud/home/vpulagura/experiment/AutoencoderModels/downsampledata_PandasMeanNew/{inverter}.csv')
            df_inv_0['Timestamp'] = pd.to_datetime(df_inv_0['Timestamp'])
            df_inv_0.sort_values(by='Timestamp', inplace=True)
            df_inv_0 = df_inv_0.set_index(df_inv_0['Timestamp'])

            format = '%Y-%m-%d %H:%M:%S'
            error_date = datetime.strptime(df_errors[(df_errors['Inverter'] == inverter) & (df_errors['had_failure'] == True)]['failure_time'].values[0][0:19], format)
            start_days = 30+dayStart
            start_date = error_date-timedelta(days= start_days)
            end_date = error_date+timedelta(days= 1*30)
            split_date = error_date-timedelta(days= 1*30)
            df_inv_0 = df_inv_0[(df_inv_0.index >= start_date) & (df_inv_0.index < end_date)]
            df_inv_0 = pd.get_dummies(df_inv_0)

            for feat in tot_feat:
                if feat not in df_inv_0.columns:
                    df_inv_0[feat] = 0
            df_inv_0 = df_inv_0[tot_feat]
            df_inv_0 = df_inv_0.dropna()

            df_target = df_inv_0[['ErrBits']]
            tot_feat.remove('ErrBits')
            df_inv_0 = df_inv_0[tot_feat]

            Xtrain_0, Xtest_0 = df_inv_0[(df_inv_0.index >= start_date) & (df_inv_0.index< split_date)], df_inv_0[(df_inv_0.index >= split_date) & (df_inv_0.index< end_date)]
            print(error_date, start_date, split_date, end_date)
            print(df_inv_0.shape, Xtrain_0.shape, Xtest_0.shape)
            Timestamp_train_0, Timestamp_test_0 = df_inv_0[(df_inv_0.index >= start_date) & (df_inv_0.index< split_date)].index, df_inv_0[(df_inv_0.index >= split_date) & (df_inv_0.index< end_date)].index
            ytrain, ytest = df_target[(df_target.index >= start_date) & (df_target.index< split_date)], df_target[(df_target.index >= split_date) & (df_target.index< end_date)]
            print(Xtrain_0.shape)
            if Xtrain_0.shape[0]>1:
                X_scaler = MinMaxScaler()
                X_scaler.fit(Xtrain_0)
                xtrain = X_scaler.transform(Xtrain_0)
                xtest = X_scaler.transform(Xtest_0)
                model__batch_size,model__encoding_dim, model__epochs, model__layer1, model__layer2 = getHyperParams(inverter, df_hyp)
                model  = create_autoencoder_model2(layer1=model__layer1, layer2=model__layer2, encoding_dim=model__encoding_dim)
                model.fit(xtrain, xtrain, epochs=model__epochs, batch_size=model__batch_size, verbose=False,validation_split=0.1, callbacks=callback1)
                test_enc = model.predict(xtest)
                train_enc = model.predict(xtrain)

                test_mses = np.mean(np.power(xtest- test_enc, 2), axis=1)
                train_mses = np.mean(np.power(xtrain- train_enc, 2), axis=1)

                test_maes = np.mean(xtest- test_enc, axis=1)
                train_maes = np.mean(xtrain- train_enc, axis=1)

                mse_threshold = np.max(train_mses)
                mae_threshold = np.max(train_maes)

                ypred_mse = np.where(test_mses>mse_threshold,1,0)
                ypred_mae = np.where(test_maes>mae_threshold,1,0)


                test_df = pd.DataFrame(ytest)
                test_df['mse_scores'] = test_mses
                test_df['ytrue'] = np.where(test_df['ErrBits']>0, 1, 0)
                test_df['mae_scores'] = test_maes
                test_df['ypred_mse'] = ypred_mse
                test_df['ypred_mae'] = ypred_mae
                lst.append(f1_score(y_true=test_df['ytrue'], y_pred=test_df['ypred_mse']))
                test_df = test_df[['ytrue','ypred_mse','ypred_mae','mse_scores', 'mae_scores']]
                source_dict_results[f'inv_{i}'] = test_df
                
                train_df = pd.DataFrame(ytrain)
                train_df['mse_scores'] = train_mses
                train_df['ytrue'] = np.where(train_df['ErrBits']>0, 1, 0)
                train_df['mae_scores'] = train_maes
                train_df = train_df[['ytrue','mse_scores', 'mae_scores']]
                source_dict_results_train[f'inv_{i}'] = train_df
                
        dayWiseResultsTest[dayStart] = source_dict_results 
        dayWiseResultsTrain[dayStart] = source_dict_results_train
        print(lst)
        with open(f'{SMA_RESULTS_PATH_TRAIN}/train_STL_AE.pkl', 'wb') as f:
            pickle.dump(dayWiseResultsTrain, f) 
        with open(f'{SMA_RESULTS_PATH_TEST}/test_STL_AE.pkl', 'wb') as f:
            pickle.dump(dayWiseResultsTest, f)
# Out:
# 2023-08-31 19:10:00.474840: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-08-31 19:10:00.474878: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 14
# 0
# 2019-10-11 08:24:20 2019-08-28 08:24:20 2019-09-11 08:24:20 2019-11-10 08:24:20
# (14406, 137) (2761, 137) (11645, 137)
# (2761, 137)
# {'model__batch_size': 128, 'model__encoding_dim': 45, 'model__epochs': 100, 'model__layer1': 95, 'model__layer2': 48}
# 2023-08-31 19:11:45.888408: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-08-31 19:11:45.888627: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-08-31 19:11:45.888788: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-08-31 19:11:45.888944: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-08-31 19:11:45.924866: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-08-31 19:11:45.924963: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-08-31 19:11:45.924978: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-08-31 19:11:45.925521: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1
# 2019-04-02 15:20:48 2019-02-17 15:20:48 2019-03-03 15:20:48 2019-05-02 15:20:48
# (14115, 137) (2884, 137) (11231, 137)
# (2884, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 65, 'model__epochs': 150, 'model__layer1': 100, 'model__layer2': 48}
# 2
# 2018-12-28 09:46:38 2018-11-14 09:46:38 2018-11-28 09:46:38 2019-01-27 09:46:38
# (14142, 137) (2884, 137) (11258, 137)
# (2884, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 45, 'model__epochs': 150, 'model__layer1': 120, 'model__layer2': 75}
# 3
# 2018-10-13 16:26:39 2018-08-30 16:26:39 2018-09-13 16:26:39 2018-11-12 16:26:39
# (13338, 137) (2199, 137) (11139, 137)
# (2199, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 45, 'model__epochs': 150, 'model__layer1': 95, 'model__layer2': 48}
# 4
# 2018-10-13 13:18:07 2018-08-30 13:18:07 2018-09-13 13:18:07 2018-11-12 13:18:07
# (13150, 137) (2225, 137) (10925, 137)
# (2225, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 45, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 75}
# Epoch 00173: early stopping
# 5
# 2019-05-19 09:01:02 2019-04-05 09:01:02 2019-04-19 09:01:02 2019-06-18 09:01:02
# (15044, 137) (2763, 137) (12281, 137)
# (2763, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 45, 'model__epochs': 150, 'model__layer1': 75, 'model__layer2': 48}
# 6
# 2018-06-12 10:55:50 2018-04-29 10:55:50 2018-05-13 10:55:50 2018-07-12 10:55:50
# (13520, 137) (2655, 137) (10865, 137)
# (2655, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 10, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 75}
# 7
# 2019-05-27 04:57:13 2019-04-13 04:57:13 2019-04-27 04:57:13 2019-06-26 04:57:13
# (15203, 137) (2884, 137) (12319, 137)
# (2884, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 16, 'model__epochs': 150, 'model__layer1': 64, 'model__layer2': 64}
# Epoch 00134: early stopping
# 8
# 2019-09-21 15:53:48 2019-08-08 15:53:48 2019-08-22 15:53:48 2019-10-21 15:53:48
# (11485, 137) (2884, 137) (8601, 137)
# (2884, 137)
# {'model__batch_size': 128, 'model__encoding_dim': 65, 'model__epochs': 100, 'model__layer1': 95, 'model__layer2': 75}
# 9
# 2020-01-19 07:22:19 2019-12-06 07:22:19 2019-12-20 07:22:19 2020-02-18 07:22:19
# (15030, 137) (2884, 137) (12146, 137)
# (2884, 137)
# {'model__batch_size': 128, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 64, 'model__layer2': 64}
# 10
# 2019-04-10 12:17:11 2019-02-25 12:17:11 2019-03-11 12:17:11 2019-05-10 12:17:11
# (14737, 137) (2884, 137) (11853, 137)
# (2884, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 65, 'model__epochs': 150, 'model__layer1': 95, 'model__layer2': 75}
# 11
# 2019-08-18 12:36:11 2019-07-05 12:36:11 2019-07-19 12:36:11 2019-09-17 12:36:11
# (14636, 137) (2884, 137) (11752, 137)
# (2884, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 65, 'model__epochs': 100, 'model__layer1': 95, 'model__layer2': 48}
# 12
# 2019-08-24 13:13:44 2019-07-11 13:13:44 2019-07-25 13:13:44 2019-09-23 13:13:44
# (14910, 137) (2674, 137) (12236, 137)
# (2674, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 10, 'model__epochs': 200, 'model__layer1': 64, 'model__layer2': 75}
# Epoch 00177: early stopping
# 13
# 2019-11-05 11:51:23 2019-09-22 11:51:23 2019-10-06 11:51:23 2019-12-05 11:51:23
# (15006, 137) (2884, 137) (12122, 137)
# (2884, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 25, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 64}
# Epoch 00129: early stopping
# 14
# 2019-10-12 15:00:20 2019-08-29 15:00:20 2019-09-12 15:00:20 2019-11-11 15:00:20
# (15223, 137) (2884, 137) (12339, 137)
# (2884, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 10, 'model__epochs': 100, 'model__layer1': 120, 'model__layer2': 75}
# Epoch 00091: early stopping
# 15
# 2019-10-13 09:51:49 2019-08-30 09:51:49 2019-09-13 09:51:49 2019-11-12 09:51:49
# (15217, 137) (2884, 137) (12333, 137)
# (2884, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 45, 'model__epochs': 100, 'model__layer1': 100, 'model__layer2': 64}
# 16
# 2019-10-26 08:15:14 2019-09-12 08:15:14 2019-09-26 08:15:14 2019-11-25 08:15:14
# (15224, 137) (2884, 137) (12340, 137)
# (2884, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 25, 'model__epochs': 200, 'model__layer1': 75, 'model__layer2': 48}
# Epoch 00199: early stopping
# 17
# 2019-10-18 07:26:00 2019-09-04 07:26:00 2019-09-18 07:26:00 2019-11-17 07:26:00
# (15223, 137) (2884, 137) (12339, 137)
# (2884, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 25, 'model__epochs': 100, 'model__layer1': 120, 'model__layer2': 75}
# 18
# 2020-05-23 13:56:28 2020-04-09 13:56:28 2020-04-23 13:56:28 2020-06-22 13:56:28
# (15194, 137) (2884, 137) (12310, 137)
# (2884, 137)
# {'model__batch_size': 128, 'model__encoding_dim': 65, 'model__epochs': 150, 'model__layer1': 100, 'model__layer2': 64}
# [0.2103119032463399, 0.16770002952465307, 0.5060138672704118, 0.7293367855008962, 0.5287112368824431, 0.21483007209062824, 0.034640274076893796, 0.09068946292510685, 0.5625890494606147, 0.6361571464625221, 0.07971938775510204, 0.8277616279069768, 0.7276856240126383, 0.5638850889192887, 0.20847423910881244, 0.014557217953902144, 0.008460492521528933, 0.02302077484559236, 0.6192626034612491]
# 30
# 0
# 2019-10-11 08:24:20 2019-08-12 08:24:20 2019-09-11 08:24:20 2019-11-10 08:24:20
# (17702, 137) (6057, 137) (11645, 137)
# (6057, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 75}
# Epoch 00182: early stopping
# 1
# 2019-04-02 15:20:48 2019-02-01 15:20:48 2019-03-03 15:20:48 2019-05-02 15:20:48
# (17293, 137) (6062, 137) (11231, 137)
# (6062, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 16, 'model__epochs': 150, 'model__layer1': 64, 'model__layer2': 64}
# Epoch 00136: early stopping
# 2
# 2018-12-28 09:46:38 2018-10-29 09:46:38 2018-11-28 09:46:38 2019-01-27 09:46:38
# (17438, 137) (6180, 137) (11258, 137)
# (6180, 137)
# {'model__batch_size': 128, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 48}
# Epoch 00149: early stopping
# 3
# 2018-10-13 16:26:39 2018-08-14 16:26:39 2018-09-13 16:26:39 2018-11-12 16:26:39
# (16629, 137) (5490, 137) (11139, 137)
# (5490, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 45, 'model__epochs': 100, 'model__layer1': 95, 'model__layer2': 32}
# 4
# 2018-10-13 13:18:07 2018-08-14 13:18:07 2018-09-13 13:18:07 2018-11-12 13:18:07
# (16441, 137) (5516, 137) (10925, 137)
# (5516, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 16, 'model__epochs': 200, 'model__layer1': 64, 'model__layer2': 75}
# 5
# 2019-05-19 09:01:02 2019-03-20 09:01:02 2019-04-19 09:01:02 2019-06-18 09:01:02
# (18261, 137) (5980, 137) (12281, 137)
# (5980, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 45, 'model__epochs': 200, 'model__layer1': 75, 'model__layer2': 64}
# Epoch 00089: early stopping
# 6
# 2018-06-12 10:55:50 2018-04-13 10:55:50 2018-05-13 10:55:50 2018-07-12 10:55:50
# (16788, 137) (5923, 137) (10865, 137)
# (5923, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 16, 'model__epochs': 200, 'model__layer1': 75, 'model__layer2': 32}
# 7
# 2019-05-27 04:57:13 2019-03-28 04:57:13 2019-04-27 04:57:13 2019-06-26 04:57:13
# (18499, 137) (6180, 137) (12319, 137)
# (6180, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 64, 'model__layer2': 48}
# Epoch 00145: early stopping
# 8
# 2019-09-21 15:53:48 2019-07-23 15:53:48 2019-08-22 15:53:48 2019-10-21 15:53:48
# (14781, 137) (6180, 137) (8601, 137)
# (6180, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 45, 'model__epochs': 150, 'model__layer1': 120, 'model__layer2': 32}
# 9
# 2020-01-19 07:22:19 2019-11-20 07:22:19 2019-12-20 07:22:19 2020-02-18 07:22:19
# (18326, 137) (6180, 137) (12146, 137)
# (6180, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 65, 'model__epochs': 150, 'model__layer1': 95, 'model__layer2': 75}
# Epoch 00141: early stopping
# 10
# 2019-04-10 12:17:11 2019-02-09 12:17:11 2019-03-11 12:17:11 2019-05-10 12:17:11
# (18018, 137) (6165, 137) (11853, 137)
# (6165, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 16, 'model__epochs': 200, 'model__layer1': 95, 'model__layer2': 75}
# Epoch 00130: early stopping
# 11
# 2019-08-18 12:36:11 2019-06-19 12:36:11 2019-07-19 12:36:11 2019-09-17 12:36:11
# (17928, 137) (6176, 137) (11752, 137)
# (6176, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 16, 'model__epochs': 150, 'model__layer1': 75, 'model__layer2': 64}
# 12
# 2019-08-24 13:13:44 2019-06-25 13:13:44 2019-07-25 13:13:44 2019-09-23 13:13:44
# (17977, 137) (5741, 137) (12236, 137)
# (5741, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 100, 'model__layer2': 48}
# Epoch 00142: early stopping
# 13
# 2019-11-05 11:51:23 2019-09-06 11:51:23 2019-10-06 11:51:23 2019-12-05 11:51:23
# (18302, 137) (6180, 137) (12122, 137)
# (6180, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 10, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 64}
# Epoch 00199: early stopping
# 14
# 2019-10-12 15:00:20 2019-08-13 15:00:20 2019-09-12 15:00:20 2019-11-11 15:00:20
# (18498, 137) (6159, 137) (12339, 137)
# (6159, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 65, 'model__epochs': 150, 'model__layer1': 95, 'model__layer2': 32}
# 15
# 2019-10-13 09:51:49 2019-08-14 09:51:49 2019-09-13 09:51:49 2019-11-12 09:51:49
# (18495, 137) (6162, 137) (12333, 137)
# (6162, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 10, 'model__epochs': 200, 'model__layer1': 75, 'model__layer2': 64}
# 16
# 2019-10-26 08:15:14 2019-08-27 08:15:14 2019-09-26 08:15:14 2019-11-25 08:15:14
# (18520, 137) (6180, 137) (12340, 137)
# (6180, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 95, 'model__layer2': 32}
# Epoch 00132: early stopping
# 17
# 2019-10-18 07:26:00 2019-08-19 07:26:00 2019-09-18 07:26:00 2019-11-17 07:26:00
# (18519, 137) (6180, 137) (12339, 137)
# (6180, 137)
# {'model__batch_size': 128, 'model__encoding_dim': 65, 'model__epochs': 150, 'model__layer1': 95, 'model__layer2': 75}
# Epoch 00148: early stopping
# 18
# 2020-05-23 13:56:28 2020-03-24 13:56:28 2020-04-23 13:56:28 2020-06-22 13:56:28
# (18490, 137) (6180, 137) (12310, 137)
# (6180, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 64}
# Epoch 00141: early stopping
# [0.7640241075567918, 0.20159716060337177, 0.9845559845559845, 0.7452935789152336, 0.5357228195937873, 0.6622222222222223, 0.48504983388704315, 0.2690929142542046, 0.9860764012852552, 0.8366895330825403, 0.14094775212636693, 0.9439655172413793, 0.9488599768130878, 0.5982583454281567, 0.6560250391236306, 0.017899199246349504, 0.008470730600514296, 0.025134099616858238, 0.9129229062673322]
# 90
# 0
# 2019-10-11 08:24:20 2019-06-13 08:24:20 2019-09-11 08:24:20 2019-11-10 08:24:20
# (30062, 137) (18417, 137) (11645, 137)
# (18417, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 16, 'model__epochs': 100, 'model__layer1': 120, 'model__layer2': 75}
# Epoch 00075: early stopping
# 1
# 2019-04-02 15:20:48 2018-12-03 15:20:48 2019-03-03 15:20:48 2019-05-02 15:20:48
# (28024, 137) (16793, 137) (11231, 137)
# (16793, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 45, 'model__epochs': 150, 'model__layer1': 64, 'model__layer2': 32}
# Epoch 00109: early stopping
# 2
# 2018-12-28 09:46:38 2018-08-30 09:46:38 2018-11-28 09:46:38 2019-01-27 09:46:38
# (29714, 137) (18456, 137) (11258, 137)
# (18456, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 10, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 75}
# Epoch 00138: early stopping
# 3
# 2018-10-13 16:26:39 2018-06-15 16:26:39 2018-09-13 16:26:39 2018-11-12 16:26:39
# (28080, 137) (16941, 137) (11139, 137)
# (16941, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 10, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 75}
# Epoch 00125: early stopping
# 4
# 2018-10-13 13:18:07 2018-06-15 13:18:07 2018-09-13 13:18:07 2018-11-12 13:18:07
# (28575, 137) (17650, 137) (10925, 137)
# (17650, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 65, 'model__epochs': 150, 'model__layer1': 100, 'model__layer2': 75}
# Epoch 00058: early stopping
# 5
# 2019-05-19 09:01:02 2019-01-19 09:01:02 2019-04-19 09:01:02 2019-06-18 09:01:02
# (29940, 137) (17659, 137) (12281, 137)
# (17659, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 45, 'model__epochs': 150, 'model__layer1': 75, 'model__layer2': 64}
# Epoch 00068: early stopping
# 6
# 2018-06-12 10:55:50 2018-02-12 10:55:50 2018-05-13 10:55:50 2018-07-12 10:55:50
# (29018, 137) (18153, 137) (10865, 137)
# (18153, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 75, 'model__layer2': 32}
# Epoch 00101: early stopping
# 7
# 2019-05-27 04:57:13 2019-01-27 04:57:13 2019-04-27 04:57:13 2019-06-26 04:57:13
# (30829, 137) (18510, 137) (12319, 137)
# (18510, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 25, 'model__epochs': 150, 'model__layer1': 120, 'model__layer2': 75}
# Epoch 00093: early stopping
# 8
# 2019-09-21 15:53:48 2019-05-24 15:53:48 2019-08-22 15:53:48 2019-10-21 15:53:48
# (27102, 137) (18501, 137) (8601, 137)
# (18501, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 16, 'model__epochs': 200, 'model__layer1': 64, 'model__layer2': 32}
# Epoch 00123: early stopping
# 9
# 2020-01-19 07:22:19 2019-09-21 07:22:19 2019-12-20 07:22:19 2020-02-18 07:22:19
# (30686, 137) (18540, 137) (12146, 137)
# (18540, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 16, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 64}
# Epoch 00075: early stopping
# 10
# 2019-04-10 12:17:11 2018-12-11 12:17:11 2019-03-11 12:17:11 2019-05-10 12:17:11
# (30378, 137) (18525, 137) (11853, 137)
# (18525, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 45, 'model__epochs': 150, 'model__layer1': 120, 'model__layer2': 48}
# Epoch 00076: early stopping
# 11
# 2019-08-18 12:36:11 2019-04-20 12:36:11 2019-07-19 12:36:11 2019-09-17 12:36:11
# (29930, 137) (18178, 137) (11752, 137)
# (18178, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 64}
# Epoch 00118: early stopping
# 12
# 2019-08-24 13:13:44 2019-04-26 13:13:44 2019-07-25 13:13:44 2019-09-23 13:13:44
# (28151, 137) (15915, 137) (12236, 137)
# (15915, 137)
# {'model__batch_size': 256, 'model__encoding_dim': 25, 'model__epochs': 150, 'model__layer1': 120, 'model__layer2': 48}
# 13
# 2019-11-05 11:51:23 2019-07-08 11:51:23 2019-10-06 11:51:23 2019-12-05 11:51:23
# (30662, 137) (18540, 137) (12122, 137)
# (18540, 137)
# {'model__batch_size': 128, 'model__encoding_dim': 65, 'model__epochs': 200, 'model__layer1': 95, 'model__layer2': 75}
# Epoch 00090: early stopping
# 14
# 2019-10-12 15:00:20 2019-06-14 15:00:20 2019-09-12 15:00:20 2019-11-11 15:00:20
# (30278, 137) (17939, 137) (12339, 137)
# (17939, 137)
# {'model__batch_size': 128, 'model__encoding_dim': 65, 'model__epochs': 150, 'model__layer1': 120, 'model__layer2': 48}
# Epoch 00130: early stopping
# 15
# 2019-10-13 09:51:49 2019-06-15 09:51:49 2019-09-13 09:51:49 2019-11-12 09:51:49
# (30725, 137) (18392, 137) (12333, 137)
# (18392, 137)
# {'model__batch_size': 128, 'model__encoding_dim': 25, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 64}
# Epoch 00112: early stopping
# 16
# 2019-10-26 08:15:14 2019-06-28 08:15:14 2019-09-26 08:15:14 2019-11-25 08:15:14
# (30765, 137) (18425, 137) (12340, 137)
# (18425, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 16, 'model__epochs': 200, 'model__layer1': 100, 'model__layer2': 64}
# Epoch 00108: early stopping
# 17
# 2019-10-18 07:26:00 2019-06-20 07:26:00 2019-09-18 07:26:00 2019-11-17 07:26:00
# (30278, 137) (17939, 137) (12339, 137)
# (17939, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 10, 'model__epochs': 100, 'model__layer1': 75, 'model__layer2': 64}
# 18
# 2020-05-23 13:56:28 2020-01-24 13:56:28 2020-04-23 13:56:28 2020-06-22 13:56:28
# (30843, 137) (18533, 137) (12310, 137)
# (18533, 137)
# {'model__batch_size': 64, 'model__encoding_dim': 10, 'model__epochs': 200, 'model__layer1': 120, 'model__layer2': 64}
# Epoch 00106: early stopping
# [0.9792038027332145, 0.20163294284700034, 0.9817871371656233, 0.7454452926208651, 0.5357228195937873, 0.9761347683668694, 0.7891891891891891, 0.6887791107974595, 0.9963846710050615, 0.9581430745814307, 0.6844741235392321, 0.9809071274298057, 0.9980978260869565, 0.9990300678952473, 0.9990448901623686, 0.8857142857142858, 0.8666666666666666, 0.05764125900644672, 0.7922348788705278]

# %%
import pickle
SMA_RESULTS_PATH_TRAIN = f'/mnt/stud/home/vpulagura/experiment/SMA_2W_1M_3M/Results/Iter{itr}/train/'
with open(f'{SMA_RESULTS_PATH_TEST}/test_STL_AE.pkl', 'rb') as f:
    df = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2147235/2907334439.py in <module>
#       1 with open(f'{SMA_RESULTS_PATH_TEST}/test_STL_AE.pkl', 'rb') as f:
# ----> 2     df = pickle.load(dayWiseResultsTest)
#
# TypeError: file must have 'read' and 'readline' attributes
